# %%
print("      *      ")
print("     ***     ")
print("    *****    ")
print("      *      ")
print("      *      ")
print("      *      ")
# Out:
#       *
#      ***
#     *****
#       *
#       *
#       *

# %% [markdown]
# #受難日第一天 20190923
#
#
# #程式超簡單

# %%
print('Hello MyDearGreatTeacher:')
